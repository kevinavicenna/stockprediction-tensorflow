# %% [markdown]
# # Implementation LSTM model for Forecasting
# ### 'My Stock Forecast App'

# %%
import yfinance as yf
from datetime import date
import pandas as pd
import numpy as np
from sklearn import metrics
from math import sqrt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## DATA INGESTION

# %%
# Input dari pengguna untuk simbol saham
symbol = input("Input simbol saham (e.g 'BBRI.JK'): ")
start_date = date(2019, 1, 1)
end_date = date(2024, 2, 1)

# Mengunduh data saham dari Yahoo Finance
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# c:\Users\kevin\miniconda3\envs\tf\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head(5)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-01  3327.215332  3327.215332  3327.215332  3327.215332  2594.003906
# 2019-01-02  3281.761475  3309.033691  3263.580078  3281.761475  2558.566406
# 2019-01-03  3254.489258  3309.033691  3254.489258  3290.852295  2565.653809
# 2019-01-04  3290.852295  3327.215332  3281.761475  3327.215332  2594.003906
# 2019-01-07  3363.578369  3372.668945  3327.215332  3327.215332  2594.003906
#
#                Volume
# Date
# 2019-01-01          0
# 2019-01-02   82441033
# 2019-01-03  102805905
# 2019-01-04  125907734
# 2019-01-07   82106628

# %%
data.reset_index(inplace=True)

# Input dari pengguna untuk fitur yang akan digunakan
input_feat = input("Input feature yang akan digunakan (e.g: Open, High, Low, Close, Adj Close, Volume): ")

# Memilih kolom tanggal dan fitur yang akan digunakan
data = data[["Date", input_feat]]
print(data.shape)
data
# Out:
# (1254, 2)
#            Date        Close
# 0    2019-01-01  3327.215332
# 1    2019-01-02  3281.761475
# 2    2019-01-03  3290.852295
# 3    2019-01-04  3327.215332
# 4    2019-01-07  3327.215332
# ...         ...          ...
# 1249 2024-01-25  5525.000000
# 1250 2024-01-26  5425.000000
# 1251 2024-01-29  5575.000000
# 1252 2024-01-30  5625.000000
# 1253 2024-01-31  5700.000000
#
# [1254 rows x 2 columns]

# %% [markdown]
# ## DATA PROCESSING

# %%
# Melakukan scaling feature
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[input_feat].values.reshape(-1, 1))

# print(scaled_data)
# print(dir(scaled_data))

# %%
# Pembagian data menjadi data training dan data testing
train_size = int(len(scaled_data) * 0.8)
train_data, test_data = scaled_data[:train_size, :], scaled_data[train_size:, :]

print(train_data)
print(train_data.shape)
# print(dir(train_data))

print(test_data)
print(test_data.shape)
print(train_size)
# Out:
# [[0.34934613]
#  [0.33762308]
#  [0.3399677 ]
#  ...
#  [0.62087085]
#  [0.65182017]
#  [0.64666195]]
# (1003, 1)
# [[0.65697839]
#  [0.66729483]
#  [0.67761127]
#  [0.68019038]
#  [0.69050682]
#  [0.68276949]
#  [0.66729483]
#  [0.67503216]
#  [0.68792771]
#  [0.68019038]
#  [0.67245305]
#  [0.69824415]
#  [0.67761127]
#  [0.71629792]
#  [0.71371881]
#  [0.71629792]
#  [0.72661436]
#  [0.73177258]
#  [0.74466813]
#  [0.72919347]
#  [0.74724724]
#  [0.74724724]
#  [0.74724724]
#  [0.74982635]
#  [0.74982635]
#  [0.73435169]
#  [0.71887703]
#  [0.72919347]
#  [0.71887703]
#  [0.73177258]
#  [0.69566504]
#  [0.70856059]
#  [0.72403525]
#  [0.71887703]
#  [0.72661436]
#  [0.73950991]
#  [0.73950991]
#  [0.73177258]
#  [0.73435169]
#  [0.7369308 ]
#  [0.70598148]
#  [0.70340237]
#  [0.7111397 ]
#  [0.75498457]
#  [0.74982635]
#  [0.75498457]
#  [0.72145614]
#  [0.71371881]
#  [0.72145614]
#  [0.73177258]
#  [0.71629792]
#  [0.7111397 ]
#  [0.72919347]
#  [0.73435169]
#  [0.7369308 ]
#  [0.73950991]
#  [0.74466813]
#  [0.74982635]
#  [0.7627219 ]
#  [0.77561744]
#  [0.80011899]
#  [0.77819655]
#  [0.76788011]
#  [0.78722344]
#  [0.81946231]
#  [0.80656676]
#  [0.81946231]
#  [0.80656676]
#  [0.81946231]
#  [0.83880564]
#  [0.80656676]
#  [0.81301454]
#  [0.81946231]
#  [0.81946231]
#  [0.81946231]
#  [0.81946231]
#  [0.83235786]
#  [0.83235786]
#  [0.88394006]
#  [0.89038783]
#  [0.90973116]
#  [0.93552225]
#  [0.90328338]
#  [0.93552225]
#  [0.9226267 ]
#  [0.90973116]
#  [0.92907448]
#  [0.89038783]
#  [0.89683561]
#  [0.88394006]
#  [0.90328338]
#  [0.89038783]
#  [0.88394006]
#  [0.9226267 ]
#  [0.9226267 ]
#  [0.91617893]
#  [0.9226267 ]
#  [0.91617893]
#  [0.9226267 ]
#  [0.92907448]
#  [0.90328338]
#  [0.88394006]
#  [0.89683561]
#  [0.89038783]
#  [0.90328338]
#  [0.89683561]
#  [0.89683561]
#  [0.89038783]
#  [0.87749228]
#  [0.88394006]
#  [0.89038783]
#  [0.89683561]
#  [0.89683561]
#  [0.91617893]
#  [0.92907448]
#  [0.94197003]
#  [0.94197003]
#  [0.94197003]
#  [0.93552225]
#  [0.9484178 ]
#  [0.95486558]
#  [0.9484178 ]
#  [0.96131335]
#  [0.9484178 ]
#  [0.96131335]
#  [0.96131335]
#  [0.96131335]
#  [0.92907448]
#  [0.96131335]
#  [0.94197003]
#  [0.96131335]
#  [0.96131335]
#  [0.9484178 ]
#  [0.9484178 ]
#  [0.92907448]
#  [0.91617893]
#  [0.92907448]
#  [0.90973116]
#  [0.92907448]
#  [0.93552225]
#  [0.9226267 ]
#  [0.93552225]
#  [0.9226267 ]
#  [0.93552225]
#  [0.91617893]
#  [0.9226267 ]
#  [0.92907448]
#  [0.94197003]
#  [0.94197003]
#  [0.92907448]
#  [0.89683561]
#  [0.87104451]
#  [0.89038783]
#  [0.87749228]
#  [0.88394006]
#  [0.89038783]
#  [0.87749228]
#  [0.86459673]
#  [0.87749228]
#  [0.87749228]
#  [0.87104451]
#  [0.87104451]
#  [0.85814896]
#  [0.83235786]
#  [0.83880564]
#  [0.83880564]
#  [0.84525341]
#  [0.85170118]
#  [0.84525341]
#  [0.82591009]
#  [0.82591009]
#  [0.81301454]
#  [0.82591009]
#  [0.84525341]
#  [0.85814896]
#  [0.85170118]
#  [0.84525341]
#  [0.81946231]
#  [0.81946231]
#  [0.78077566]
#  [0.79367121]
#  [0.78077566]
#  [0.80656676]
#  [0.82591009]
#  [0.76014279]
#  [0.78077566]
#  [0.78077566]
#  [0.77045922]
#  [0.7369308 ]
#  [0.78077566]
#  [0.80656676]
#  [0.83235786]
#  [0.84525341]
#  [0.83880564]
#  [0.83235786]
#  [0.80011899]
#  [0.78722344]
#  [0.80011899]
#  [0.84525341]
#  [0.84525341]
#  [0.83880564]
#  [0.84525341]
#  [0.83235786]
#  [0.85170118]
#  [0.87104451]
#  [0.88394006]
#  [0.87104451]
#  [0.87104451]
#  [0.85814896]
#  [0.85170118]
#  [0.87104451]
#  [0.90973116]
#  [0.89683561]
#  [0.89038783]
#  [0.90328338]
#  [0.87749228]
#  [0.85814896]
#  [0.86459673]
#  [0.85814896]
#  [0.9226267 ]
#  [0.9226267 ]
#  [0.90973116]
#  [0.9226267 ]
#  [0.9226267 ]
#  [0.92907448]
#  [0.95486558]
#  [0.94197003]
#  [0.96776113]
#  [0.96776113]
#  [0.95486558]
#  [0.93552225]
#  [0.96131335]
#  [0.9742089 ]
#  [0.94197003]
#  [0.96131335]
#  [0.96131335]
#  [0.9742089 ]
#  [1.        ]
#  [0.99355223]
#  [0.99355223]
#  [0.98065668]
#  [0.9742089 ]
#  [0.98710445]
#  [0.98065668]
#  [0.96131335]
#  [0.9484178 ]
#  [0.91617893]
#  [0.89038783]
#  [0.92907448]
#  [0.94197003]
#  [0.96131335]]
# (251, 1)
# 1003

# %%
# Persiapan data untuk model LSTM
def create_sequences(data, sequence_length):
    sequences = []
    target = []
    for i in range(len(data) - sequence_length):
        sequences.append(data[i:i+sequence_length])
        target.append(data[i+sequence_length])
    return np.array(sequences), np.array(target)

# %%
tf.random.set_seed(7)

# %%
sequence_length = 3
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# input_dim_size = 10000
# embedding_dim_size = 100

# %% [markdown]
# # Modelling

# %%
# Membangun model LSTM
# model = Sequential()
# model.add(Embedding(input_dim=input_dim_size, output_dim=embedding_dim_size, input_length=sequence_length))
# model.add(LSTM(units=128, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=64))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(units=1, activation='relu'))
# model.summary()

# model = Sequential()
# model.add(Embedding(input_dim=input_dim_size, output_dim=embedding_dim_size, input_length=sequence_length))
# model.add(LSTM(units=128, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=64))
# model.add(Dropout(0.2))
# model.add(Dense(units=1, activation='relu'))
# model.summary()

# model = Sequential()
# model.add(LSTM(units=128, return_sequences=True, input_shape=(sequence_length, 1)))
# model.add(Dropout(0.2))
# model.add(LSTM(units=64))
# model.add(Dropout(0.2))
# model.add(Dense(units=1, activation='relu'))
# model.summary()


model = Sequential()

# Add the first LSTM layer with dropout
model.add(LSTM(units=128, return_sequences=True, input_shape=(sequence_length, 1)))
model.add(Dropout(0.2))

# Add the second LSTM layer with dropout
model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.2))

# Add the third LSTM layer with dropout
model.add(LSTM(units=32))
model.add(Dropout(0.2))

# Add a dense layer for output
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Print the model summary
model.summary()




# model = Sequential()

# model.add(LSTM(units=256, return_sequences=True, input_shape=(sequence_length, 1)))
# model.add(Dropout(0.2))

# model.add(LSTM(units=128, return_sequences=True))
# model.add(Dropout(0.2))

# model.add(LSTM(units=64, return_sequences=True))
# model.add(Dropout(0.2))

# model.add(LSTM(units=32))
# model.add(Dropout(0.2))

# model.add(Dense(units=64, activation='relu'))
# model.add(Dense(units=32, activation='relu'))
# model.add(Dense(units=1))
# model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_38 (LSTM)              (None, 3, 128)            66560
#
#  dropout_38 (Dropout)        (None, 3, 128)            0
#
#  lstm_39 (LSTM)              (None, 3, 64)             49408
#
#  dropout_39 (Dropout)        (None, 3, 64)             0
#
#  lstm_40 (LSTM)              (None, 32)                12416
#
#  dropout_40 (Dropout)        (None, 32)                0
#
#  dense_29 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 128,417
# Trainable params: 128,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# optimizer = Adam(learning_rate=0.001)
optimizer = Adam(learning_rate=0.005)
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_absolute_error'])
model_final = model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[ early_stopping], validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 16/16 - 6s - loss: 0.0614 - mean_absolute_error: 0.1931 - val_loss: 0.0826 - val_mean_absolute_error: 0.2803 - 6s/epoch - 360ms/step
# Epoch 2/100
# 16/16 - 0s - loss: 0.0135 - mean_absolute_error: 0.0918 - val_loss: 0.0379 - val_mean_absolute_error: 0.1877 - 253ms/epoch - 16ms/step
# Epoch 3/100
# 16/16 - 0s - loss: 0.0066 - mean_absolute_error: 0.0630 - val_loss: 7.0636e-04 - val_mean_absolute_error: 0.0211 - 235ms/epoch - 15ms/step
# Epoch 4/100
# 16/16 - 0s - loss: 0.0038 - mean_absolute_error: 0.0483 - val_loss: 9.5142e-04 - val_mean_absolute_error: 0.0253 - 259ms/epoch - 16ms/step
# Epoch 5/100
# 16/16 - 0s - loss: 0.0032 - mean_absolute_error: 0.0442 - val_loss: 7.1313e-04 - val_mean_absolute_error: 0.0215 - 220ms/epoch - 14ms/step
# Epoch 6/100
# 16/16 - 0s - loss: 0.0030 - mean_absolute_error: 0.0427 - val_loss: 7.3482e-04 - val_mean_absolute_error: 0.0219 - 216ms/epoch - 13ms/step
# Epoch 7/100
# 16/16 - 0s - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 0.0028 - val_mean_absolute_error: 0.0478 - 214ms/epoch - 13ms/step
# Epoch 8/100
# 16/16 - 0s - loss: 0.0029 - mean_absolute_error: 0.0423 - val_loss: 7.4369e-04 - val_mean_absolute_error: 0.0220 - 213ms/epoch - 13ms/step
# Epoch 9/100
# 16/16 - 0s - loss: 0.0032 - mean_absolute_error: 0.0440 - val_loss: 0.0011 - val_mean_absolute_error: 0.0271 - 224ms/epoch - 14ms/step
# Epoch 10/100
# 16/16 - 0s - loss: 0.0025 - mean_absolute_error: 0.0393 - val_loss: 0.0016 - val_mean_absolute_error: 0.0336 - 244ms/epoch - 15ms/step
# Epoch 11/100
# 16/16 - 0s - loss: 0.0027 - mean_absolute_error: 0.0405 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395 - 281ms/epoch - 18ms/step
# Epoch 12/100
# 16/16 - 0s - loss: 0.0028 - mean_absolute_error: 0.0404 - val_loss: 5.5242e-04 - val_mean_absolute_error: 0.0181 - 259ms/epoch - 16ms/step
# Epoch 13/100
# 16/16 - 0s - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0028 - val_mean_absolute_error: 0.0472 - 262ms/epoch - 16ms/step
# Epoch 14/100
# 16/16 - 0s - loss: 0.0024 - mean_absolute_error: 0.0382 - val_loss: 0.0020 - val_mean_absolute_error: 0.0396 - 230ms/epoch - 14ms/step
# Epoch 15/100
# 16/16 - 0s - loss: 0.0023 - mean_absolute_error: 0.0381 - val_loss: 8.5196e-04 - val_mean_absolute_error: 0.0238 - 214ms/epoch - 13ms/step
# Epoch 16/100
# 16/16 - 0s - loss: 0.0030 - mean_absolute_error: 0.0428 - val_loss: 5.5204e-04 - val_mean_absolute_error: 0.0183 - 226ms/epoch - 14ms/step
# Epoch 17/100
# 16/16 - 0s - loss: 0.0025 - mean_absolute_error: 0.0390 - val_loss: 0.0049 - val_mean_absolute_error: 0.0656 - 252ms/epoch - 16ms/step
# Epoch 18/100
# 16/16 - 0s - loss: 0.0027 - mean_absolute_error: 0.0409 - val_loss: 0.0055 - val_mean_absolute_error: 0.0699 - 242ms/epoch - 15ms/step
# Epoch 19/100
# 16/16 - 0s - loss: 0.0026 - mean_absolute_error: 0.0399 - val_loss: 0.0033 - val_mean_absolute_error: 0.0514 - 230ms/epoch - 14ms/step
# Epoch 20/100
# 16/16 - 0s - loss: 0.0024 - mean_absolute_error: 0.0385 - val_loss: 0.0019 - val_mean_absolute_error: 0.0376 - 245ms/epoch - 15ms/step
# Epoch 21/100
# 16/16 - 0s - loss: 0.0023 - mean_absolute_error: 0.0372 - val_loss: 8.1379e-04 - val_mean_absolute_error: 0.0230 - 257ms/epoch - 16ms/step
# Epoch 22/100
# 16/16 - 0s - loss: 0.0021 - mean_absolute_error: 0.0352 - val_loss: 0.0028 - val_mean_absolute_error: 0.0466 - 215ms/epoch - 13ms/step
# Epoch 23/100
# 16/16 - 0s - loss: 0.0021 - mean_absolute_error: 0.0352 - val_loss: 5.3027e-04 - val_mean_absolute_error: 0.0176 - 236ms/epoch - 15ms/step
# Epoch 24/100
# 16/16 - 0s - loss: 0.0021 - mean_absolute_error: 0.0350 - val_loss: 7.5427e-04 - val_mean_absolute_error: 0.0223 - 228ms/epoch - 14ms/step
# Epoch 25/100
# 16/16 - 0s - loss: 0.0019 - mean_absolute_error: 0.0339 - val_loss: 7.2783e-04 - val_mean_absolute_error: 0.0218 - 221ms/epoch - 14ms/step
# Epoch 26/100
# 16/16 - 0s - loss: 0.0019 - mean_absolute_error: 0.0338 - val_loss: 0.0015 - val_mean_absolute_error: 0.0330 - 219ms/epoch - 14ms/step
# Epoch 27/100
# 16/16 - 0s - loss: 0.0019 - mean_absolute_error: 0.0336 - val_loss: 0.0025 - val_mean_absolute_error: 0.0446 - 202ms/epoch - 13ms/step
# Epoch 28/100
# 16/16 - 0s - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0028 - val_mean_absolute_error: 0.0471 - 239ms/epoch - 15ms/step
# Epoch 29/100
# 16/16 - 0s - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 6.4189e-04 - val_mean_absolute_error: 0.0203 - 287ms/epoch - 18ms/step
# Epoch 30/100
# 16/16 - 0s - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297 - 278ms/epoch - 17ms/step
# Epoch 31/100
# 16/16 - 0s - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0016 - val_mean_absolute_error: 0.0345 - 262ms/epoch - 16ms/step
# Epoch 32/100
# 16/16 - 0s - loss: 0.0017 - mean_absolute_error: 0.0324 - val_loss: 0.0024 - val_mean_absolute_error: 0.0438 - 260ms/epoch - 16ms/step
# Epoch 33/100
# Restoring model weights from the end of the best epoch: 23.
# 16/16 - 0s - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 6.9026e-04 - val_mean_absolute_error: 0.0212 - 286ms/epoch - 18ms/step
# Epoch 33: early stopping

# %% [markdown]
# # Evaluation

# %%
# Evaluasi model pada data uji
loss = model.evaluate(X_test, y_test)
round_loss = [round(num, 5) for num in loss]
print("Loss :", round_loss)

predict = model.predict(X_test)
# print(predict)
# Out:
# 8/8 [==============================] - 0s 8ms/step - loss: 5.3027e-04 - mean_absolute_error: 0.0176
# Loss : [0.00053, 0.01759]
# 8/8 [==============================] - 1s 5ms/step

# %%
print("-"*15, " Metric ","-"*15)
print('RMSE : ', round(sqrt(metrics.mean_squared_error(y_test, predict)), 5))
print('MSE  : ', round(abs(metrics.mean_squared_error(y_test, predict)), 5))
print('MAE  : ', round(metrics.mean_absolute_error(y_test, predict), 5))
# Out:
# ---------------  Metric  ---------------
# RMSE :  0.02303
# MSE  :  0.00053
# MAE  :  0.01759

# %% [markdown]
# # Visualization

# %%
# Plot loss
sns.set(style="whitegrid")

sns.lineplot(x=range(len(model_final.history['loss'])), y=model_final.history['loss'], label='Training Loss')
sns.lineplot(x=range(len(model_final.history['val_loss'])), y=model_final.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()

# %% [markdown]
# # Saving Model

# %%
import time

ts = int(time.time())
file_path = f"../lstm_stock/{ts}/"
model.save(filepath=file_path, save_format='tf')
# model.save("../lstm_model3.keras")
print("Sucess saving model!")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_38_layer_call_fn, lstm_cell_38_layer_call_and_return_conditional_losses, lstm_cell_39_layer_call_fn, lstm_cell_39_layer_call_and_return_conditional_losses, lstm_cell_40_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../lstm_stock/1713725037/assets
# INFO:tensorflow:Assets written to: ../lstm_stock/1713725037/assets
# Sucess saving model!
