# %%
import yfinance as yf
from datetime import date
import pandas as pd
import numpy as np
from sklearn import metrics
from math import sqrt
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Data Input

# %%
# Input dari pengguna untuk simbol saham
symbol = input("Input simbol saham (e.g 'BBRI.JK'): ")
start_date = date(2023, 12, 1)
end_date = date(2024, 2, 1)

# Mengunduh data saham dari Yahoo Finance
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# c:\Users\kevin\miniconda3\envs\tf\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head(5)
# Out:
#               Open    High     Low   Close    Adj Close     Volume
# Date
# 2023-12-01  5275.0  5375.0  5275.0  5350.0  5077.938965   99499500
# 2023-12-04  5450.0  5575.0  5450.0  5500.0  5220.311035  235595700
# 2023-12-05  5425.0  5500.0  5425.0  5450.0  5172.854004  114689900
# 2023-12-06  5425.0  5450.0  5400.0  5425.0  5149.125000  119716700
# 2023-12-07  5400.0  5475.0  5400.0  5475.0  5196.582520  102126600

# %%
data.reset_index(inplace=True)

# Input dari pengguna untuk fitur yang akan digunakan
input_feat = input("Input feature yang akan digunakan (e.g: Open,High,Low,Close,Adj Close,Volume): ")

# Memilih kolom tanggal dan fitur yang akan digunakan
data = data[["Date", input_feat]]
print(data.shape)
print(data)
# Out:
# (41, 2)
#          Date   Close
# 0  2023-12-01  5350.0
# 1  2023-12-04  5500.0
# 2  2023-12-05  5450.0
# 3  2023-12-06  5425.0
# 4  2023-12-07  5475.0
# 5  2023-12-08  5375.0
# 6  2023-12-11  5300.0
# 7  2023-12-12  5325.0
# 8  2023-12-13  5300.0
# 9  2023-12-14  5550.0
# 10 2023-12-15  5550.0
# 11 2023-12-18  5500.0
# 12 2023-12-19  5550.0
# 13 2023-12-20  5550.0
# 14 2023-12-21  5575.0
# 15 2023-12-22  5675.0
# 16 2023-12-27  5625.0
# 17 2023-12-28  5725.0
# 18 2023-12-29  5725.0
# 19 2024-01-02  5675.0
# 20 2024-01-03  5600.0
# 21 2024-01-04  5700.0
# 22 2024-01-05  5750.0
# 23 2024-01-08  5625.0
# 24 2024-01-09  5700.0
# 25 2024-01-10  5700.0
# 26 2024-01-11  5750.0
# 27 2024-01-12  5850.0
# 28 2024-01-15  5825.0
# 29 2024-01-16  5825.0
# 30 2024-01-17  5775.0
# 31 2024-01-18  5750.0
# 32 2024-01-19  5800.0
# 33 2024-01-22  5775.0
# 34 2024-01-23  5700.0
# 35 2024-01-24  5650.0
# 36 2024-01-25  5525.0
# 37 2024-01-26  5425.0
# 38 2024-01-29  5575.0
# 39 2024-01-30  5625.0
# 40 2024-01-31  5700.0

# %%
# Melakukan penskalaan fitur
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[input_feat].values.reshape(-1, 1))

print(scaled_data)
print(dir(scaled_data))
# Out:
# [[0.09090909]
#  [0.36363636]
#  [0.27272727]
#  [0.22727273]
#  [0.31818182]
#  [0.13636364]
#  [0.        ]
#  [0.04545455]
#  [0.        ]
#  [0.45454545]
#  [0.45454545]
#  [0.36363636]
#  [0.45454545]
#  [0.45454545]
#  [0.5       ]
#  [0.68181818]
#  [0.59090909]
#  [0.77272727]
#  [0.77272727]
#  [0.68181818]
#  [0.54545455]
#  [0.72727273]
#  [0.81818182]
#  [0.59090909]
#  [0.72727273]
#  [0.72727273]
#  [0.81818182]
#  [1.        ]
#  [0.95454545]
#  [0.95454545]
#  [0.86363636]
#  [0.81818182]
#  [0.90909091]
#  [0.86363636]
#  [0.72727273]
#  [0.63636364]
#  [0.40909091]
#  [0.22727273]
#  [0.5       ]
#  [0.59090909]
#  [0.72727273]]
# ['T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_function__', '__array_interface__', '__array_prepare__', '__array_priority__', '__array_struct__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__class_getitem__', '__complex__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__divmod__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__xor__', 'all', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'astype', 'base', 'byteswap', 'choose', 'clip', 'compress', 'conj', 'conjugate', 'copy', 'ctypes', 'cumprod', 'cumsum', 'data', 'diagonal', 'dot', 'dtype', 'dump', 'dumps', 'fill', 'flags', 'flat', 'flatten', 'getfield', 'imag', 'item', 'itemset', 'itemsize', 'max', 'mean', 'min', 'nbytes', 'ndim', 'newbyteorder', 'nonzero', 'partition', 'prod', 'ptp', 'put', 'ravel', 'real', 'repeat', 'reshape', 'resize', 'round', 'searchsorted', 'setfield', 'setflags', 'shape', 'size', 'sort', 'squeeze', 'std', 'strides', 'sum', 'swapaxes', 'take', 'tobytes', 'tofile', 'tolist', 'tostring', 'trace', 'transpose', 'var', 'view']

# %%
# Pembagian data menjadi data latih dan data uji
train_size = int(len(scaled_data) * 0.8)
train_data, test_data = scaled_data[:train_size, :], scaled_data[train_size:, :]


print(train_data)
print(train_data.shape)
print(dir(train_data))
# Out:
# [[0.09090909]
#  [0.36363636]
#  [0.27272727]
#  [0.22727273]
#  [0.31818182]
#  [0.13636364]
#  [0.        ]
#  [0.04545455]
#  [0.        ]
#  [0.45454545]
#  [0.45454545]
#  [0.36363636]
#  [0.45454545]
#  [0.45454545]
#  [0.5       ]
#  [0.68181818]
#  [0.59090909]
#  [0.77272727]
#  [0.77272727]
#  [0.68181818]
#  [0.54545455]
#  [0.72727273]
#  [0.81818182]
#  [0.59090909]
#  [0.72727273]
#  [0.72727273]
#  [0.81818182]
#  [1.        ]
#  [0.95454545]
#  [0.95454545]
#  [0.86363636]
#  [0.81818182]]
# (32, 1)
# ['T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_function__', '__array_interface__', '__array_prepare__', '__array_priority__', '__array_struct__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__class_getitem__', '__complex__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__divmod__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__xor__', 'all', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'astype', 'base', 'byteswap', 'choose', 'clip', 'compress', 'conj', 'conjugate', 'copy', 'ctypes', 'cumprod', 'cumsum', 'data', 'diagonal', 'dot', 'dtype', 'dump', 'dumps', 'fill', 'flags', 'flat', 'flatten', 'getfield', 'imag', 'item', 'itemset', 'itemsize', 'max', 'mean', 'min', 'nbytes', 'ndim', 'newbyteorder', 'nonzero', 'partition', 'prod', 'ptp', 'put', 'ravel', 'real', 'repeat', 'reshape', 'resize', 'round', 'searchsorted', 'setfield', 'setflags', 'shape', 'size', 'sort', 'squeeze', 'std', 'strides', 'sum', 'swapaxes', 'take', 'tobytes', 'tofile', 'tolist', 'tostring', 'trace', 'transpose', 'var', 'view']

# %%
# Persiapan data untuk model LSTM
def create_sequences(data, sequence_length):
    sequences = []
    target = []
    for i in range(len(data) - sequence_length):
        sequences.append(data[i:i+sequence_length])
        target.append(data[i+sequence_length])
    return np.array(sequences), np.array(target)

sequence_length = 10  # Anda dapat mengubah panjangnya sesuai kebutuhan
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

input_dim_size = 10000  # Contoh: Anda membatasi kosakata hingga 10.000 kata paling umum.
embedding_dim_size = 100  # Contoh: Gunakan embedding dengan dimensi 100.

# %%
# Membangun model LSTM
model = Sequential()
model.add(Embedding(input_dim=input_dim_size, output_dim=embedding_dim_size, input_length=sequence_length))
model.add(LSTM(units=128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='relu'))
model.summary()

# Membangun model LSTM
# model = Sequential()
# model.add(Embedding(input_dim=input_dim_size, output_dim=embedding_dim_size, input_length=sequence_length))
# model.add(LSTM(units=128, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(units=64))
# model.add(Dropout(0.2))
# model.add(Dense(units=1, activation='relu'))
# model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 10, 100)           1000000
#
#  lstm_6 (LSTM)               (None, 10, 128)           117248
#
#  dropout_6 (Dropout)         (None, 10, 128)           0
#
#  lstm_7 (LSTM)               (None, 64)                49408
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,169,825
# Trainable params: 1,169,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Kompilasi dan pelatihan model
cp3 = ModelCheckpoint('../model/model3/', save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)


optimizer = Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_absolute_error'])
history = model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=2, callbacks=[cp3, early_stopping], validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 3s - loss: 0.5112 - mean_absolute_error: 0.6929 - 3s/epoch - 3s/step
# Epoch 2/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.4774 - mean_absolute_error: 0.6679 - 63ms/epoch - 63ms/step
# Epoch 3/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.4428 - mean_absolute_error: 0.6403 - 70ms/epoch - 70ms/step
# Epoch 4/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.3979 - mean_absolute_error: 0.6053 - 50ms/epoch - 50ms/step
# Epoch 5/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.3571 - mean_absolute_error: 0.5680 - 52ms/epoch - 52ms/step
# Epoch 6/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.2681 - mean_absolute_error: 0.4877 - 46ms/epoch - 46ms/step
# Epoch 7/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.2198 - mean_absolute_error: 0.4177 - 62ms/epoch - 62ms/step
# Epoch 8/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.1081 - mean_absolute_error: 0.2910 - 81ms/epoch - 81ms/step
# Epoch 9/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0492 - mean_absolute_error: 0.1944 - 56ms/epoch - 56ms/step
# Epoch 10/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0832 - mean_absolute_error: 0.2440 - 55ms/epoch - 55ms/step
# Epoch 11/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.1344 - mean_absolute_error: 0.2882 - 53ms/epoch - 53ms/step
# Epoch 12/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.1139 - mean_absolute_error: 0.2665 - 58ms/epoch - 58ms/step
# Epoch 13/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0554 - mean_absolute_error: 0.1852 - 57ms/epoch - 57ms/step
# Epoch 14/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0554 - mean_absolute_error: 0.1820 - 52ms/epoch - 52ms/step
# Epoch 15/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0426 - mean_absolute_error: 0.1709 - 47ms/epoch - 47ms/step
# Epoch 16/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0596 - mean_absolute_error: 0.1986 - 53ms/epoch - 53ms/step
# Epoch 17/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0610 - mean_absolute_error: 0.2110 - 54ms/epoch - 54ms/step
# Epoch 18/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0748 - mean_absolute_error: 0.2212 - 63ms/epoch - 63ms/step
# Epoch 19/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0634 - mean_absolute_error: 0.2077 - 47ms/epoch - 47ms/step
# Epoch 20/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0671 - mean_absolute_error: 0.2245 - 47ms/epoch - 47ms/step
# Epoch 21/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0647 - mean_absolute_error: 0.2113 - 62ms/epoch - 62ms/step
# Epoch 22/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0764 - mean_absolute_error: 0.2175 - 56ms/epoch - 56ms/step
# Epoch 23/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0626 - mean_absolute_error: 0.2034 - 59ms/epoch - 59ms/step
# Epoch 24/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0401 - mean_absolute_error: 0.1684 - 56ms/epoch - 56ms/step
# Epoch 25/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0278 - mean_absolute_error: 0.1449 - 66ms/epoch - 66ms/step
# Epoch 26/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0339 - mean_absolute_error: 0.1506 - 53ms/epoch - 53ms/step
# Epoch 27/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0467 - mean_absolute_error: 0.1652 - 55ms/epoch - 55ms/step
# Epoch 28/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0580 - mean_absolute_error: 0.1946 - 55ms/epoch - 55ms/step
# Epoch 29/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0680 - mean_absolute_error: 0.2299 - 56ms/epoch - 56ms/step
# Epoch 30/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0527 - mean_absolute_error: 0.1943 - 56ms/epoch - 56ms/step
# Epoch 31/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.1735 - 70ms/epoch - 70ms/step
# Epoch 32/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0396 - mean_absolute_error: 0.1611 - 62ms/epoch - 62ms/step
# Epoch 33/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0317 - mean_absolute_error: 0.1379 - 59ms/epoch - 59ms/step
# Epoch 34/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.1465 - 54ms/epoch - 54ms/step
# Epoch 35/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.1552 - 55ms/epoch - 55ms/step
# Epoch 36/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0535 - mean_absolute_error: 0.2004 - 54ms/epoch - 54ms/step
# Epoch 37/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0427 - mean_absolute_error: 0.1648 - 53ms/epoch - 53ms/step
# Epoch 38/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0333 - mean_absolute_error: 0.1560 - 54ms/epoch - 54ms/step
# Epoch 39/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0419 - mean_absolute_error: 0.1790 - 53ms/epoch - 53ms/step
# Epoch 40/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0431 - mean_absolute_error: 0.1675 - 54ms/epoch - 54ms/step
# Epoch 41/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0603 - mean_absolute_error: 0.2094 - 54ms/epoch - 54ms/step
# Epoch 42/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.1653 - 53ms/epoch - 53ms/step
# Epoch 43/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0427 - mean_absolute_error: 0.1755 - 53ms/epoch - 53ms/step
# Epoch 44/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.1492 - 57ms/epoch - 57ms/step
# Epoch 45/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0639 - mean_absolute_error: 0.2035 - 54ms/epoch - 54ms/step
# Epoch 46/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0551 - mean_absolute_error: 0.1907 - 63ms/epoch - 63ms/step
# Epoch 47/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0427 - mean_absolute_error: 0.1696 - 57ms/epoch - 57ms/step
# Epoch 48/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0682 - mean_absolute_error: 0.2158 - 56ms/epoch - 56ms/step
# Epoch 49/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0502 - mean_absolute_error: 0.1846 - 55ms/epoch - 55ms/step
# Epoch 50/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0443 - mean_absolute_error: 0.1784 - 56ms/epoch - 56ms/step
# Epoch 51/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.1586 - 52ms/epoch - 52ms/step
# Epoch 52/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0570 - mean_absolute_error: 0.1953 - 42ms/epoch - 42ms/step
# Epoch 53/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0512 - mean_absolute_error: 0.1668 - 56ms/epoch - 56ms/step
# Epoch 54/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.1534 - 39ms/epoch - 39ms/step
# Epoch 55/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0459 - mean_absolute_error: 0.1774 - 43ms/epoch - 43ms/step
# Epoch 56/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0571 - mean_absolute_error: 0.2021 - 42ms/epoch - 42ms/step
# Epoch 57/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.1691 - 40ms/epoch - 40ms/step
# Epoch 58/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.1483 - 42ms/epoch - 42ms/step
# Epoch 59/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.1591 - 41ms/epoch - 41ms/step
# Epoch 60/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0389 - mean_absolute_error: 0.1463 - 46ms/epoch - 46ms/step
# Epoch 61/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0507 - mean_absolute_error: 0.1867 - 39ms/epoch - 39ms/step
# Epoch 62/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0528 - mean_absolute_error: 0.1865 - 42ms/epoch - 42ms/step
# Epoch 63/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0384 - mean_absolute_error: 0.1626 - 40ms/epoch - 40ms/step
# Epoch 64/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.1579 - 40ms/epoch - 40ms/step
# Epoch 65/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0433 - mean_absolute_error: 0.1653 - 42ms/epoch - 42ms/step
# Epoch 66/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0484 - mean_absolute_error: 0.1764 - 41ms/epoch - 41ms/step
# Epoch 67/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0393 - mean_absolute_error: 0.1446 - 42ms/epoch - 42ms/step
# Epoch 68/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.1686 - 39ms/epoch - 39ms/step
# Epoch 69/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0422 - mean_absolute_error: 0.1611 - 39ms/epoch - 39ms/step
# Epoch 70/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0534 - mean_absolute_error: 0.1937 - 44ms/epoch - 44ms/step
# Epoch 71/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0310 - mean_absolute_error: 0.1350 - 40ms/epoch - 40ms/step
# Epoch 72/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.1675 - 44ms/epoch - 44ms/step
# Epoch 73/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.1483 - 45ms/epoch - 45ms/step
# Epoch 74/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0442 - mean_absolute_error: 0.1690 - 41ms/epoch - 41ms/step
# Epoch 75/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0474 - mean_absolute_error: 0.1792 - 40ms/epoch - 40ms/step
# Epoch 76/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0252 - mean_absolute_error: 0.1363 - 41ms/epoch - 41ms/step
# Epoch 77/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0437 - mean_absolute_error: 0.1781 - 41ms/epoch - 41ms/step
# Epoch 78/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.1434 - 39ms/epoch - 39ms/step
# Epoch 79/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.1409 - 53ms/epoch - 53ms/step
# Epoch 80/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0439 - mean_absolute_error: 0.1677 - 42ms/epoch - 42ms/step
# Epoch 81/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.1600 - 40ms/epoch - 40ms/step
# Epoch 82/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.1541 - 41ms/epoch - 41ms/step
# Epoch 83/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.1467 - 39ms/epoch - 39ms/step
# Epoch 84/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0454 - mean_absolute_error: 0.1656 - 41ms/epoch - 41ms/step
# Epoch 85/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0299 - mean_absolute_error: 0.1290 - 40ms/epoch - 40ms/step
# Epoch 86/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0461 - mean_absolute_error: 0.1638 - 39ms/epoch - 39ms/step
# Epoch 87/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0515 - mean_absolute_error: 0.2028 - 41ms/epoch - 41ms/step
# Epoch 88/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0422 - mean_absolute_error: 0.1699 - 38ms/epoch - 38ms/step
# Epoch 89/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0255 - mean_absolute_error: 0.1252 - 43ms/epoch - 43ms/step
# Epoch 90/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0379 - mean_absolute_error: 0.1564 - 42ms/epoch - 42ms/step
# Epoch 91/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0391 - mean_absolute_error: 0.1680 - 57ms/epoch - 57ms/step
# Epoch 92/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0406 - mean_absolute_error: 0.1617 - 55ms/epoch - 55ms/step
# Epoch 93/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0511 - mean_absolute_error: 0.1989 - 54ms/epoch - 54ms/step
# Epoch 94/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0585 - mean_absolute_error: 0.1836 - 52ms/epoch - 52ms/step
# Epoch 95/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0397 - mean_absolute_error: 0.1705 - 54ms/epoch - 54ms/step
# Epoch 96/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0427 - mean_absolute_error: 0.1547 - 55ms/epoch - 55ms/step
# Epoch 97/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0212 - mean_absolute_error: 0.1177 - 52ms/epoch - 52ms/step
# Epoch 98/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0498 - mean_absolute_error: 0.1842 - 53ms/epoch - 53ms/step
# Epoch 99/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.1697 - 53ms/epoch - 53ms/step
# Epoch 100/100
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_absolute_error
# 1/1 - 0s - loss: 0.0358 - mean_absolute_error: 0.1650 - 54ms/epoch - 54ms/step

# %%
# Plot loss
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# Plot metrik lainnya (jika ada)
# Misalnya, jika Anda memiliki metrik akurasi:
# plt.plot(history.history['accuracy'], label='Training Accuracy')
# plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %%
# Evaluasi model pada data uji
loss = model.evaluate(X_test, y_test)
print("Loss di data uji:", loss)

print("Loss di data uji:", loss)
predict = model.predict(X_test)
# print(predict)
# Out:
# c:\Users\kevin\miniconda3\envs\tf\lib\site-packages\keras\utils\generic_utils.py:993: RuntimeWarning: divide by zero encountered in log10
#   numdigits = int(np.log10(self.target)) + 1
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Evaluasi model pada data uji
# ----> 2 loss = model.evaluate(X_test, y_test)
#       3 print("Loss di data uji:", loss)
#       5 print("Loss di data uji:", loss)
#
# File c:\Users\kevin\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\kevin\miniconda3\envs\tf\lib\site-packages\keras\utils\generic_utils.py:993, in Progbar.update(self, current, values, finalize)
#     990     message += "\n"
#     992 if self.target is not None:
# --> 993     numdigits = int(np.log10(self.target)) + 1
#     994     bar = ("%" + str(numdigits) + "d/%d [") % (current, self.target)
#     995     prog = float(current) / self.target
#
# OverflowError: cannot convert float infinity to integer

# %%
print("-"*50, " Metric ","-"*50)
print('RMSE : ',sqrt(metrics.mean_squared_error(y_test,predict)))
print('MSE  :  ',metrics.mean_squared_error(y_test,predict))
print('MAE  :  ',metrics.mean_absolute_error(y_test,predict))
print("-"*26, " Mengecek Apakah Nilainya Overfit atau tidak ","-"*26)

# %%
# Simpan model
import time

ts = int(time.time())
file_path = f"./lstm_stock/{ts}/"
model.save(filepath=file_path, save_format='tf')
model.save("../home-page-stock-prediction/lstm_model3.keras")
print("Sucess saving model!)
